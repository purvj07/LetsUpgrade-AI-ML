# %%
import pandas as pd
dataset= pd.read_csv('general_data.csv')
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
Attrition_Yes = dataset[dataset['Attrition']=='Yes']
Attrition_Yes.describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  711.000000        711.000000  711.000000          711.0   711.000000
# mean    33.607595          9.012658    2.877637            1.0  2191.767932
# std      9.675693          7.772368    1.014233            0.0  1270.136654
# min     18.000000          1.000000    1.000000            1.0     2.000000
# 25%     28.000000          2.000000    2.000000            1.0  1072.000000
# 50%     32.000000          7.000000    3.000000            1.0  2165.000000
# 75%     39.000000         15.000000    4.000000            1.0  3341.000000
# max     58.000000         29.000000    5.000000            1.0  4403.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  711.000000     711.000000          707.000000         711.000000
# mean     2.037975   61682.616034            2.936351          15.481013
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dummy = pd.get_dummies(dataset['Attrition'])
dummy.head()
# Out:
#    No  Yes
# 0   1    0
# 1   0    1
# 2   1    0
# 3   1    0
# 4   1    0

# %%
dataset1 = pd.concat((dataset,dummy),axis=1)
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    PercentSalaryHike StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
dataset1.drop(['Attrition'],axis=1,inplace=True)

# %%
dataset1.drop(['No'],axis=1,inplace=True)
dataset1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-e88bf1849dd2> in <module>
# ----> 1 dataset1.drop(['No'],axis=1,inplace=True)
#       2 dataset1.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
dataset1.rename(columns={"Yes":"Attrition1"},inplace=True)

# %% [markdown]
# # Hypotheis1
# H0:Age has no significance over attrition
#
# H1:Age has significance over attrition

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset1.Attrition1,dataset1.Age)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.15920500686577965 1.996801615886744e-26
# Reject H0

# %% [markdown]
# here the value of r is negative so both the attribute are negatively correlated and the graph will be straight line in downward direction.

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset1.Attrition1,dataset1.Age)

# %%
#dataset1.corr()

# %% [markdown]
# # Hypothesis 2
# H0:DistanceFromHome	 has no significance over attrition
#
# H1:DistanceFromHome	 has significance over attrition

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset1.Attrition1,dataset1.DistanceFromHome)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.009730141010179674 0.5182860428050771
# Null hypothesis is Accepted

# %%
plt.scatter(dataset1.Attrition1,dataset1.DistanceFromHome)

# %% [markdown]
# # Hypothesis 3
# H0:Education has no significance over attrition
#
# H1:Education has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.Education)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.015111167710968713 0.3157293177118575
# Null hypothesis is Accepted

# %% [markdown]
# # Hypothesis 4
# H0:PercentSalaryHike has no significance over attrition
#
# H1:PercentSalaryHike has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.PercentSalaryHike	)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# 0.03253259489105349 0.030743386433355353
# Reject H0

# %% [markdown]
# # Hypothesis 5
# H0:StockOptionLevel	 has no significance over attrition
#
# H1:StockOptionLevel	 has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.StockOptionLevel)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.006838852403261513 0.6498072937475723
# Null hypothesis is Accepted

# %% [markdown]
# # Hypothesis 6
# H0:TrainingTimesLastYear has no significance over attrition
#
# H1:TrainingTimesLastYear has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.TrainingTimesLastYear)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.049430576244255 0.0010247061915365072
# Reject H0

# %% [markdown]
# # Hypothesis 7
# H0:YearsAtCompany has no significance over attrition
#
# H1:YearsAtCompany has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.YearsAtCompany)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.1343922139899772 3.1638831224877484e-19
# Reject H0

# %% [markdown]
# # Hypothesis 8
# H0:YearsSinceLastPromotion has no significance over attrition
#
# H1:YearsSinceLastPromotion has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.YearsSinceLastPromotion)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.03301877514258434 0.028330336189396753
# Reject H0

# %% [markdown]
# # Hypothesis 9
# H0:YearsWithCurrManager has no significance over attrition
#
# H1:YearsWithCurrManager has significance over attrition

# %%
stats,p=pearsonr(dataset1.Attrition1,dataset1.YearsWithCurrManager)
print(stats,p)
if (p<0.05):
    print("Reject H0")
elif (p>=0.05):
    print("Null hypothesis is Accepted")
# Out:
# -0.15619931590162847 1.7339322652896276e-25
# Reject H0

# %% [markdown]
# # Hypothesis 10
# H0:Gender has no significance over attrition
#
# H1:Gender has significance over attrition
